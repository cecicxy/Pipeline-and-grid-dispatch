# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
distances = pd.read_csv('data/geodata process/distance.csv', index_col=0)
distances
# Out:
#                     Beijing      Tianjin        Hebei       Shanxi
# Beijing            0.000000   110.003361   224.418701   406.036237  \
# Tianjin          110.003361     0.000000   192.933531   429.770471
# Hebei            224.418701   192.933531     0.000000   259.315353
# Shanxi           406.036237   429.770471   259.315353     0.000000
# Inner Mongolia   451.535830   554.672663   531.685916   445.522850
# Liaoning         621.971180   601.056023   792.812008  1023.483202
# Jilin            860.203885   859.246155  1052.106990  1266.210725
# Heilongjiang    1249.863325  1273.454285  1461.829012  1645.460596
# Shanghai        1074.359837   966.501145   940.693998  1109.006074
# Jiangsu          925.494706   821.429451   771.702052   923.983699
# Zhejiang        1126.575740  1023.179758   966.174890  1100.410845
# Anhui            899.107927   808.659900   705.595027   795.777445
# Fujian          1548.081350  1454.711889  1354.825180  1417.843176
# ...

# %%
(distances.sum().sum()/2)/((1+distances.shape[0])*distances.shape[0]/2)
# Out:
# 1318.529682004032

# %%
distances.loc['Taiwan',:]=distances.loc['Fujian',:]
distances.loc[:,'Taiwan']=distances.loc[:,'Fujian']
distances.loc['Hong Kong']=distances.loc['Guangdong',:]
distances.loc[:,'Hong Kong']=distances.loc['Guangdong',:]
distances.loc['Macao']=distances.loc['Guangdong',:]
distances.loc[:,'Macao']=distances.loc['Guangdong',:]
distances
# Out:
#                     Beijing      Tianjin        Hebei       Shanxi
# Beijing            0.000000   110.003361   224.418701   406.036237  \
# Tianjin          110.003361     0.000000   192.933531   429.770471
# Hebei            224.418701   192.933531     0.000000   259.315353
# Shanxi           406.036237   429.770471   259.315353     0.000000
# Inner Mongolia   451.535830   554.672663   531.685916   445.522850
# Liaoning         621.971180   601.056023   792.812008  1023.483202
# Jilin            860.203885   859.246155  1052.106990  1266.210725
# Heilongjiang    1249.863325  1273.454285  1461.829012  1645.460596
# Shanghai        1074.359837   966.501145   940.693998  1109.006074
# Jiangsu          925.494706   821.429451   771.702052   923.983699
# Zhejiang        1126.575740  1023.179758   966.174890  1100.410845
# Anhui            899.107927   808.659900   705.595027   795.777445
# Fujian          1548.081350  1454.711889  1354.825180  1417.843176
# ...

# %%
distances.fillna(0, inplace=True)
distances.to_csv('data/geodata process/distance.csv')
# loss=0.03/1000*distances+1
# loss.to_csv('data/cable/loss.csv')

# %%
(distances.sum().sum()/2)/((1+distances.shape[0])*distances.shape[0]/2)
# Out:
# 1320.7601181512605
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
